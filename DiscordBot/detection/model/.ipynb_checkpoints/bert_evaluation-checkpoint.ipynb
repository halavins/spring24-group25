# %%
import json
from datetime import datetime
import io
import json
import logging
import os
import random
import re
import textwrap
from collections import deque

import discord
import matplotlib.pyplot as plt
import numpy as np
from openai import OpenAI
import pandas as pd
import torch
from torch.utils.data import Dataset
import json
from openai import OpenAI

with open('../synthetic/synthetic_full.json', 'r') as json_file:
    results = json.load(json_file)

# %%
import os
token_path = '../../tokens.json'
if not os.path.isfile(token_path):
    raise Exception(f"{token_path} not found!")
with open(token_path) as f:
    # If you get an error here, it means your token is formatted incorrectly. Did you put it in quotes?
    tokens = json.load(f)
    discord_token = tokens['discord']
    openai_token = tokens['openai']

# %%
import json

def read_jsonl_file(filename):
    data = []
    with open(filename, 'r') as f:
        for line in f:
            data.append(json.loads(line.strip()))
    return data

# Example usage
gpt4turbo_filename = 'batch_output-gpt-4turbo.jsonl'
gpt4o_file_name = 'batch_output-gpt-4o.jsonl'

gpt4turbo_raw = read_jsonl_file(gpt4turbo_filename)
gpt4o_raw = read_jsonl_file(gpt4o_file_name)

# %%
len(results)
# Out:
# 630

# %%
gpt4_turbo = [(
    z[0]['is_scam'], 
    int(z[1]['response']['body']['choices'][0]['message']['function_call']['arguments'].split("score\":")[1].split(',')[0])) for z in zip(results, gpt4turbo_raw)
        ]

gpt4_o = [(
    z[0]['is_scam'], 
    int(z[1]['response']['body']['choices'][0]['message']['function_call']['arguments'].split("score\":")[1].split(',')[0]) if len(z[1]['response']['body']['choices'][0]['message']['function_call']['arguments']) > 2 else None) for z in zip(results, gpt4o_raw)
        ]

# %%
# Helper function to extract labels and scores
def extract_labels_scores(data):
    true_labels = [item[0] for item in data if item[1] is not None]
    scores = [item[1] for item in data if item[1] is not None]
    return true_labels, scores

# Extract labels and scores for both models
true_labels_turbo, scores_turbo = extract_labels_scores(gpt4_turbo)
true_labels_o, scores_o = extract_labels_scores(gpt4_o)

# Compute Precision-Recall and ROC curve values for GPT-4 Turbo
precision_turbo, recall_turbo, pr_thresholds_turbo = precision_recall_curve(true_labels_turbo, scores_turbo)
roc_fpr_turbo, roc_tpr_turbo, roc_thresholds_turbo = roc_curve(true_labels_turbo, scores_turbo)
roc_auc_turbo = auc(roc_fpr_turbo, roc_tpr_turbo)

# Compute Precision-Recall and ROC curve values for GPT-4o
precision_o, recall_o, pr_thresholds_o = precision_recall_curve(true_labels_o, scores_o)
roc_fpr_o, roc_tpr_o, roc_thresholds_o = roc_curve(true_labels_o, scores_o)
roc_auc_o = auc(roc_fpr_o, roc_tpr_o)

# Plot Precision-Recall curves
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(recall_turbo, precision_turbo, marker='.', label='GPT-4 Turbo PR curve', color='blue')
plt.plot(recall_o, precision_o, marker='.', label='GPT-4o PR curve', color='red')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()

# Annotate PR curves with threshold values
for i in range(len(pr_thresholds_turbo)):
    if i % (len(pr_thresholds_turbo) // 10) == 0:  # Annotate every 10th threshold
        plt.annotate(f'{pr_thresholds_turbo[i]:.2f}', (recall_turbo[i], precision_turbo[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')

for i in range(len(pr_thresholds_o)):
    if i % (len(pr_thresholds_o) // 10) == 0:  # Annotate every 10th threshold
        plt.annotate(f'{pr_thresholds_o[i]:.2f}', (recall_o[i], precision_o[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

# Plot ROC curves
plt.subplot(1, 2, 2)
plt.plot(roc_fpr_turbo, roc_tpr_turbo, marker='.', label=f'GPT-4 Turbo ROC curve (area = {roc_auc_turbo:.2f})', color='blue')
plt.plot(roc_fpr_o, roc_tpr_o, marker='.', label=f'GPT-4o ROC curve (area = {roc_auc_o:.2f})', color='red')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()

# Annotate ROC curves with threshold values
for i in range(len(roc_thresholds_turbo)):
    if i % (len(roc_thresholds_turbo) // 10) == 0:  # Annotate every 10th threshold
        plt.annotate(f'{roc_thresholds_turbo[i]:.2f}', (roc_fpr_turbo[i], roc_tpr_turbo[i]), textcoords="offset points", xytext=(0,10), ha='center', color='blue')

for i in range(len(roc_thresholds_o)):
    if i % (len(roc_thresholds_o) // 10) == 0:  # Annotate every 10th threshold
        plt.annotate(f'{roc_thresholds_o[i]:.2f}', (roc_fpr_o[i], roc_tpr_o[i]), textcoords="offset points", xytext=(0,10), ha='center', color='red')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve, auc


def plot_confusion_matrix(y_true, y_pred, threshold=0.5, title='Confusion Matrix'):
    """
    Plots the confusion matrix given true labels and predicted scores/labels.
    
    Parameters:
    - y_true: List of true labels.
    - y_pred: List of predicted scores or labels.
    - threshold: Threshold for converting scores to labels (used if y_pred are scores).
    - title: Title for the plot.
    """
    # Convert predicted scores to labels based on the threshold
    y_pred_labels = [1 if score >= threshold else 0 for score in y_pred]
    
    cm = confusion_matrix(y_true, y_pred_labels)
    
    fig, ax = plt.subplots()
    cax = ax.matshow(cm, cmap=plt.cm.Blues)
    fig.colorbar(cax)
    
    for (i, j), val in np.ndenumerate(cm):
        ax.text(j, i, f'{val}', ha='center', va='center')
    
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title("LLM Confusion Matrix")
    plt.xticks([0, 1], ['Not Scam', 'Scam'])
    plt.yticks([0, 1], ['Not Scam', 'Scam'])
    plt.show()

# %%
plot_confusion_matrix(true_labels_o, scores_o, threshold=40)

# %%
type(true_labels_o[0])
# Out:
# bool
